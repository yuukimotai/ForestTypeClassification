# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

data_list = []
data_list.append(pd.read_csv("train/train.tsv", delimiter='\t', index_col=0))
df = pd.concat(data_list)

# %%
cover_type1 = df[df['Cover_Type'] == 1]
cover_type2 = df[df['Cover_Type'] == 2]
cover_type3 = df[df['Cover_Type'] == 3]
cover_type4 = df[df['Cover_Type'] == 4]
cover_type5 = df[df['Cover_Type'] == 5]
cover_type6 = df[df['Cover_Type'] == 6]
cover_type7 = df[df['Cover_Type'] == 7]

# %%
fig, axes = plt.subplots(7, 1, figsize=(10, 10))
axes[0].hist(cover_type1["Hillshade_9am"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[1].hist(cover_type2["Hillshade_9am"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[2].hist(cover_type3["Hillshade_9am"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[3].hist(cover_type4["Hillshade_9am"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[4].hist(cover_type5["Hillshade_9am"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[5].hist(cover_type6["Hillshade_9am"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[6].hist(cover_type7["Hillshade_9am"],bins=200)# 午前9時の陰影起伏 （夏至）

plt.show()

# %%
fig, axes = plt.subplots(7, 1, figsize=(10, 10))
axes[0].hist(cover_type1["Hillshade_Noon"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[1].hist(cover_type2["Hillshade_Noon"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[2].hist(cover_type3["Hillshade_Noon"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[3].hist(cover_type4["Hillshade_Noon"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[4].hist(cover_type5["Hillshade_Noon"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[5].hist(cover_type6["Hillshade_Noon"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[6].hist(cover_type7["Hillshade_Noon"],bins=200)# 午前9時の陰影起伏 （夏至）

plt.show()

# %%
fig, axes = plt.subplots(7, 1, figsize=(10, 10))
axes[0].hist(cover_type1["Hillshade_3pm"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[1].hist(cover_type2["Hillshade_3pm"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[2].hist(cover_type3["Hillshade_3pm"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[3].hist(cover_type4["Hillshade_3pm"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[4].hist(cover_type5["Hillshade_3pm"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[5].hist(cover_type6["Hillshade_3pm"],bins=200)# 午前9時の陰影起伏 （夏至）
axes[6].hist(cover_type7["Hillshade_3pm"],bins=200)# 午前9時の陰影起伏 （夏至）

plt.show()
